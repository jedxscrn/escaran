# %% [markdown]
# #### imports (essentials, image processing, machine learning)

# %%
import numpy as np
import pandas as pd

import cv2
from colorthief import ColorThief

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### using colorthief to extract dominant color from pokemon image

# %%
def get_dominant_color_colorthief(image_path):
    # Initialize ColorThief with the image
    color_thief = ColorThief(image_path)
    
    # Get the dominant color
    dominant_color = color_thief.get_color(quality=1)
    
    return dominant_color

# %% [markdown]
# #### reading data and extracting dominant color

# %%
data = pd.read_csv('pokemon.csv')
color_features = []

for name in data['Name']:
    image_path = f'images/{name}.png'
    
    try:
        dominant_color = get_dominant_color_colorthief(image_path)
    except:
        print(f"Could not process image for {name}")
        dominant_color = [0, 0, 0]  # Default value or handle as needed
    
    color_features.append(dominant_color)

# %% [markdown]
# #### splitting data for training

# %%
x = color_features
y = data['Type1']
z = data['Type2']
a = data['Name']
test_size = 0.5

x_train, x_test, y_train, y_test, z_train, z_test, a_train, a_test = train_test_split(x, y, z, a, stratify=y, test_size=test_size)

# %% [markdown]
# #### training model

# %%
clf = RandomForestClassifier(n_estimators=1000)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# %% [markdown]
# #### testing model (at least 1 predicted type from primary or secondary types)

# %%
correct_predictions = 0
types_correctly_predicted = np.array([])
for pred, truetype, truetype2, name in zip(y_pred, y_test, z_test, a_test):
    if pd.notna(truetype2) and truetype2 != '':
        print(f"\n{name}\npredicted: {pred}\nreal type: {truetype} and {truetype2}")
    else:
        print(f"\n{name}\npredicted: {pred}\nreal type: {truetype}")
    if pred == truetype or pred == truetype2:
        correct_predictions += 1
        print(f'SUCCESSFUL PREDICTIONS = {correct_predictions}')
    else: print("Failed")
# Out:
# shiftry
# predicted: Ghost
# real type: Grass and Dark
# Failed
#
# bellossom
# predicted: Electric
# real type: Grass
# Failed
#
# skrelp
# predicted: Poison
# real type: Poison and Water
# SUCCESSFUL PREDICTIONS = 1
#
# bouffalant
# predicted: Dark
# real type: Normal
# Failed
#
# mewtwo
# predicted: Dragon
# real type: Psychic
# Failed
#
# duskull
# predicted: Grass
# real type: Ghost
# Failed
#
# braixen
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 2
#
# fomantis
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 3
#
# magearna
# predicted: Normal
# real type: Steel and Fairy
# Failed
#
# muk
# predicted: Ghost
# real type: Poison
# Failed
#
# skiploom
# predicted: Bug
# real type: Grass and Flying
# Failed
#
# tyranitar
# predicted: Grass
# real type: Rock and Dark
# Failed
#
# ducklett
# predicted: Water
# real type: Water and Flying
# SUCCESSFUL PREDICTIONS = 4
#
# ralts
# predicted: Grass
# real type: Psychic and Fairy
# Failed
#
# mienshao
# predicted: Fire
# real type: Fighting
# Failed
#
# altaria
# predicted: Water
# real type: Dragon and Flying
# Failed
#
# furret
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 5
#
# dwebble
# predicted: Bug
# real type: Bug and Rock
# SUCCESSFUL PREDICTIONS = 6
#
# manectric
# predicted: Grass
# real type: Electric
# Failed
#
# kyogre
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 7
#
# xatu
# predicted: Bug
# real type: Psychic and Flying
# Failed
#
# typhlosion
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 8
#
# audino
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 9
#
# weavile
# predicted: Bug
# real type: Dark and Ice
# Failed
#
# magmar
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 10
#
# mantine
# predicted: Fighting
# real type: Water and Flying
# Failed
#
# arcanine
# predicted: Normal
# real type: Fire
# Failed
#
# charjabug
# predicted: Grass
# real type: Bug and Electric
# Failed
#
# lickitung
# predicted: Psychic
# real type: Normal
# Failed
#
# mr-mime
# predicted: Water
# real type: Psychic and Fairy
# Failed
#
# lickilicky
# predicted: Ground
# real type: Normal
# Failed
#
# gliscor
# predicted: Poison
# real type: Ground and Flying
# Failed
#
# tympole
# predicted: Normal
# real type: Water
# Failed
#
# kricketune
# predicted: Fire
# real type: Bug
# Failed
#
# treecko
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 11
#
# seviper
# predicted: Electric
# real type: Poison
# Failed
#
# tapu-fini
# predicted: Poison
# real type: Water and Fairy
# Failed
#
# garbodor
# predicted: Dragon
# real type: Poison
# Failed
#
# blitzle
# predicted: Electric
# real type: Electric
# SUCCESSFUL PREDICTIONS = 12
#
# swinub
# predicted: Normal
# real type: Ice and Ground
# Failed
#
# cyndaquil
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 13
#
# wartortle
# predicted: Psychic
# real type: Water
# Failed
#
# lombre
# predicted: Grass
# real type: Water and Grass
# SUCCESSFUL PREDICTIONS = 14
#
# haunter
# predicted: Poison
# real type: Ghost and Poison
# SUCCESSFUL PREDICTIONS = 15
#
# charmeleon
# predicted: Fighting
# real type: Fire
# Failed
#
# xerneas
# predicted: Water
# real type: Fairy
# Failed
#
# shellder
# predicted: Electric
# real type: Water
# Failed
#
# shedinja
# predicted: Bug
# real type: Bug and Ghost
# SUCCESSFUL PREDICTIONS = 16
#
# inkay
# predicted: Grass
# real type: Dark and Psychic
# Failed
#
# druddigon
# predicted: Water
# real type: Dragon
# Failed
#
# ekans
# predicted: Normal
# real type: Poison
# Failed
#
# zangoose
# predicted: Steel
# real type: Normal
# Failed
#
# klefki
# predicted: Fighting
# real type: Steel and Fairy
# Failed
#
# nidorina
# predicted: Psychic
# real type: Poison
# Failed
#
# bagon
# predicted: Water
# real type: Dragon
# Failed
#
# dewott
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 17
#
# keldeo-ordinary
# predicted: Water
# real type: Water and Fighting
# SUCCESSFUL PREDICTIONS = 18
#
# chikorita
# predicted: Psychic
# real type: Grass
# Failed
#
# patrat
# predicted: Ice
# real type: Normal
# Failed
#
# gulpin
# predicted: Psychic
# real type: Poison
# Failed
#
# venonat
# predicted: Poison
# real type: Bug and Poison
# SUCCESSFUL PREDICTIONS = 19
#
# magnezone
# predicted: Normal
# real type: Electric and Steel
# Failed
#
# noctowl
# predicted: Normal
# real type: Normal and Flying
# SUCCESSFUL PREDICTIONS = 20
#
# probopass
# predicted: Normal
# real type: Rock and Steel
# Failed
#
# skarmory
# predicted: Dragon
# real type: Steel and Flying
# Failed
#
# honchkrow
# predicted: Bug
# real type: Dark and Flying
# Failed
#
# oddish
# predicted: Grass
# real type: Grass and Poison
# SUCCESSFUL PREDICTIONS = 21
#
# primarina
# predicted: Water
# real type: Water and Fairy
# SUCCESSFUL PREDICTIONS = 22
#
# gorebyss
# predicted: Psychic
# real type: Water
# Failed
#
# blaziken
# predicted: Fire
# real type: Fire and Fighting
# SUCCESSFUL PREDICTIONS = 23
#
# kartana
# predicted: Fire
# real type: Grass and Steel
# Failed
#
# shellos
# predicted: Normal
# real type: Water
# Failed
#
# woobat
# predicted: Water
# real type: Psychic and Flying
# Failed
#
# pidgeot
# predicted: Normal
# real type: Normal and Flying
# SUCCESSFUL PREDICTIONS = 24
#
# slurpuff
# predicted: Normal
# real type: Fairy
# Failed
#
# diancie
# predicted: Poison
# real type: Rock and Fairy
# Failed
#
# shieldon
# predicted: Ghost
# real type: Rock and Steel
# Failed
#
# luxio
# predicted: Electric
# real type: Electric
# SUCCESSFUL PREDICTIONS = 25
#
# dialga
# predicted: Dark
# real type: Steel and Dragon
# Failed
#
# florges
# predicted: Grass
# real type: Fairy
# Failed
#
# dunsparce
# predicted: Water
# real type: Normal
# Failed
#
# poliwrath
# predicted: Ice
# real type: Water and Fighting
# Failed
#
# kabutops
# predicted: Psychic
# real type: Rock and Water
# Failed
#
# tropius
# predicted: Grass
# real type: Grass and Flying
# SUCCESSFUL PREDICTIONS = 26
#
# beldum
# predicted: Water
# real type: Steel and Psychic
# Failed
#
# igglybuff
# predicted: Normal
# real type: Normal and Fairy
# SUCCESSFUL PREDICTIONS = 27
#
# komala
# predicted: Water
# real type: Normal
# Failed
#
# relicanth
# predicted: Bug
# real type: Water and Rock
# Failed
#
# heliolisk
# predicted: Grass
# real type: Electric and Normal
# Failed
#
# noibat
# predicted: Normal
# real type: Flying and Dragon
# Failed
#
# paras
# predicted: Bug
# real type: Bug and Grass
# SUCCESSFUL PREDICTIONS = 28
#
# zoroark
# predicted: Ghost
# real type: Dark
# Failed
#
# torterra
# predicted: Grass
# real type: Grass and Ground
# SUCCESSFUL PREDICTIONS = 29
#
# donphan
# predicted: Rock
# real type: Ground
# Failed
#
# zweilous
# predicted: Poison
# real type: Dark and Dragon
# Failed
#
# lurantis
# predicted: Water
# real type: Grass
# Failed
#
# espeon
# predicted: Normal
# real type: Psychic
# Failed
#
# snubbull
# predicted: Grass
# real type: Fairy
# Failed
#
# porygon
# predicted: Water
# real type: Normal
# Failed
#
# fennekin
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 30
#
# togedemaru
# predicted: Dragon
# real type: Electric and Steel
# Failed
#
# whirlipede
# predicted: Normal
# real type: Bug and Poison
# Failed
#
# spheal
# predicted: Electric
# real type: Ice and Water
# Failed
#
# stakataka
# predicted: Rock
# real type: Rock and Steel
# SUCCESSFUL PREDICTIONS = 31
#
# cloyster
# predicted: Normal
# real type: Water and Ice
# Failed
#
# koffing
# predicted: Poison
# real type: Poison
# SUCCESSFUL PREDICTIONS = 32
#
# heracross
# predicted: Water
# real type: Bug and Fighting
# Failed
#
# golurk
# predicted: Grass
# real type: Ground and Ghost
# Failed
#
# bronzong
# predicted: Grass
# real type: Steel and Psychic
# Failed
#
# mesprit
# predicted: Normal
# real type: Psychic
# Failed
#
# litwick
# predicted: Ice
# real type: Ghost and Fire
# Failed
#
# emboar
# predicted: Bug
# real type: Fire and Fighting
# Failed
#
# vivillon
# predicted: Normal
# real type: Bug and Flying
# Failed
#
# sceptile
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 33
#
# delibird
# predicted: Fire
# real type: Ice and Flying
# Failed
#
# prinplup
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 34
#
# seel
# predicted: Bug
# real type: Water
# Failed
#
# braviary
# predicted: Electric
# real type: Normal and Flying
# Failed
#
# palpitoad
# predicted: Steel
# real type: Water and Ground
# Failed
#
# vulpix
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 35
#
# kyurem
# predicted: Water
# real type: Dragon and Ice
# Failed
#
# diglett
# predicted: Normal
# real type: Ground
# Failed
#
# krokorok
# predicted: Ground
# real type: Ground and Dark
# SUCCESSFUL PREDICTIONS = 36
#
# golem
# predicted: Rock
# real type: Rock and Ground
# SUCCESSFUL PREDICTIONS = 37
#
# riolu
# predicted: Poison
# real type: Fighting
# Failed
#
# swellow
# predicted: Normal
# real type: Normal and Flying
# SUCCESSFUL PREDICTIONS = 38
#
# spearow
# predicted: Rock
# real type: Normal and Flying
# Failed
#
# exeggcute
# predicted: Normal
# real type: Grass and Psychic
# Failed
#
# mandibuzz
# predicted: Ghost
# real type: Dark and Flying
# Failed
#
# pignite
# predicted: Fire
# real type: Fire and Fighting
# SUCCESSFUL PREDICTIONS = 39
#
# gothitelle
# predicted: Ghost
# real type: Psychic
# Failed
#
# huntail
# predicted: Rock
# real type: Water
# Failed
#
# pelipper
# predicted: Water
# real type: Water and Flying
# SUCCESSFUL PREDICTIONS = 40
#
# heatmor
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 41
#
# lotad
# predicted: Grass
# real type: Water and Grass
# SUCCESSFUL PREDICTIONS = 42
#
# marill
# predicted: Normal
# real type: Water and Fairy
# Failed
#
# goldeen
# predicted: Grass
# real type: Water
# Failed
#
# plusle
# predicted: Ground
# real type: Electric
# Failed
#
# lileep
# predicted: Normal
# real type: Rock and Grass
# Failed
#
# aron
# predicted: Dragon
# real type: Steel and Rock
# Failed
#
# poliwhirl
# predicted: Fighting
# real type: Water
# Failed
#
# larvitar
# predicted: Grass
# real type: Rock and Ground
# Failed
#
# serperior
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 43
#
# marshadow
# predicted: Steel
# real type: Fighting and Ghost
# Failed
#
# rotom
# predicted: Water
# real type: Electric and Ghost
# Failed
#
# blastoise
# predicted: Fighting
# real type: Water
# Failed
#
# breloom
# predicted: Grass
# real type: Grass and Fighting
# SUCCESSFUL PREDICTIONS = 44
#
# mew
# predicted: Psychic
# real type: Psychic
# SUCCESSFUL PREDICTIONS = 45
#
# finneon
# predicted: Ground
# real type: Water
# Failed
#
# remoraid
# predicted: Normal
# real type: Water
# Failed
#
# scyther
# predicted: Grass
# real type: Bug and Flying
# Failed
#
# magikarp
# predicted: Fire
# real type: Water
# Failed
#
# torchic
# predicted: Psychic
# real type: Fire
# Failed
#
# delcatty
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 46
#
# glaceon
# predicted: Grass
# real type: Ice
# Failed
#
# axew
# predicted: Ghost
# real type: Dragon
# Failed
#
# litleo
# predicted: Ghost
# real type: Fire and Normal
# Failed
#
# voltorb
# predicted: Ground
# real type: Electric
# Failed
#
# mismagius
# predicted: Dark
# real type: Ghost
# Failed
#
# pikachu
# predicted: Electric
# real type: Electric
# SUCCESSFUL PREDICTIONS = 47
#
# yveltal
# predicted: Ghost
# real type: Dark and Flying
# Failed
#
# ludicolo
# predicted: Grass
# real type: Water and Grass
# SUCCESSFUL PREDICTIONS = 48
#
# aerodactyl
# predicted: Poison
# real type: Rock and Flying
# Failed
#
# golbat
# predicted: Poison
# real type: Poison and Flying
# SUCCESSFUL PREDICTIONS = 49
#
# lumineon
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 50
#
# marowak
# predicted: Normal
# real type: Ground
# Failed
#
# mudkip
# predicted: Electric
# real type: Water
# Failed
#
# sylveon
# predicted: Normal
# real type: Fairy
# Failed
#
# galvantula
# predicted: Electric
# real type: Bug and Electric
# SUCCESSFUL PREDICTIONS = 51
#
# anorith
# predicted: Grass
# real type: Rock and Bug
# Failed
#
# bewear
# predicted: Psychic
# real type: Normal and Fighting
# Failed
#
# masquerain
# predicted: Water
# real type: Bug and Flying
# Failed
#
# exploud
# predicted: Water
# real type: Normal
# Failed
#
# sentret
# predicted: Ground
# real type: Normal
# Failed
#
# camerupt
# predicted: Fairy
# real type: Fire and Ground
# Failed
#
# tranquill
# predicted: Normal
# real type: Normal and Flying
# SUCCESSFUL PREDICTIONS = 52
#
# swampert
# predicted: Water
# real type: Water and Ground
# SUCCESSFUL PREDICTIONS = 53
#
# nuzleaf
# predicted: Rock
# real type: Grass and Dark
# Failed
#
# quilladin
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 54
#
# ursaring
# predicted: Bug
# real type: Normal
# Failed
#
# wailord
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 55
#
# regice
# predicted: Water
# real type: Ice
# Failed
#
# amaura
# predicted: Water
# real type: Rock and Ice
# Failed
#
# arbok
# predicted: Normal
# real type: Poison
# Failed
#
# cosmoem
# predicted: Normal
# real type: Psychic
# Failed
#
# octillery
# predicted: Fire
# real type: Water
# Failed
#
# trubbish
# predicted: Dragon
# real type: Poison
# Failed
#
# latios
# predicted: Water
# real type: Dragon and Psychic
# Failed
#
# mime-jr
# predicted: Normal
# real type: Psychic and Fairy
# Failed
#
# decidueye
# predicted: Normal
# real type: Grass and Ghost
# Failed
#
# scraggy
# predicted: Water
# real type: Dark and Fighting
# Failed
#
# leafeon
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 56
#
# vespiquen
# predicted: Bug
# real type: Bug and Flying
# SUCCESSFUL PREDICTIONS = 57
#
# luxray
# predicted: Electric
# real type: Electric
# SUCCESSFUL PREDICTIONS = 58
#
# goodra
# predicted: Dragon
# real type: Dragon
# SUCCESSFUL PREDICTIONS = 59
#
# azurill
# predicted: Water
# real type: Normal and Fairy
# Failed
#
# solgaleo
# predicted: Fire
# real type: Psychic and Steel
# Failed
#
# dustox
# predicted: Grass
# real type: Bug and Poison
# Failed
#
# elekid
# predicted: Electric
# real type: Electric
# SUCCESSFUL PREDICTIONS = 60
#
# carnivine
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 61
#
# zubat
# predicted: Poison
# real type: Poison and Flying
# SUCCESSFUL PREDICTIONS = 62
#
# glameow
# predicted: Bug
# real type: Normal
# Failed
#
# oricorio-baile
# predicted: Fire
# real type: Fire and Flying
# SUCCESSFUL PREDICTIONS = 63
#
# jirachi
# predicted: Electric
# real type: Steel and Psychic
# Failed
#
# luvdisc
# predicted: Psychic
# real type: Water
# Failed
#
# wobbuffet
# predicted: Water
# real type: Psychic
# Failed
#
# gengar
# predicted: Ghost
# real type: Ghost and Poison
# SUCCESSFUL PREDICTIONS = 64
#
# combee
# predicted: Bug
# real type: Bug and Flying
# SUCCESSFUL PREDICTIONS = 65
#
# lanturn
# predicted: Poison
# real type: Water and Electric
# Failed
#
# girafarig
# predicted: Water
# real type: Normal and Psychic
# Failed
#
# lampent
# predicted: Psychic
# real type: Ghost and Fire
# Failed
#
# cofagrigus
# predicted: Ghost
# real type: Ghost
# SUCCESSFUL PREDICTIONS = 66
#
# gumshoos
# predicted: Rock
# real type: Normal
# Failed
#
# raikou
# predicted: Psychic
# real type: Electric
# Failed
#
# celesteela
# predicted: Grass
# real type: Steel and Flying
# Failed
#
# tapu-lele
# predicted: Ground
# real type: Psychic and Fairy
# Failed
#
# gothita
# predicted: Fighting
# real type: Psychic
# Failed
#
# hypno
# predicted: Psychic
# real type: Psychic
# SUCCESSFUL PREDICTIONS = 67
#
# gallade
# predicted: Grass
# real type: Psychic and Fighting
# Failed
#
# unfezant
# predicted: Rock
# real type: Normal and Flying
# Failed
#
# ledyba
# predicted: Fairy
# real type: Bug and Flying
# Failed
#
# castform
# predicted: Dragon
# real type: Normal
# Failed
#
# excadrill
# predicted: Dark
# real type: Ground and Steel
# Failed
#
# cacturne
# predicted: Grass
# real type: Grass and Dark
# SUCCESSFUL PREDICTIONS = 68
#
# spritzee
# predicted: Psychic
# real type: Fairy
# Failed
#
# hawlucha
# predicted: Grass
# real type: Fighting and Flying
# Failed
#
# sandslash
# predicted: Normal
# real type: Ground
# Failed
#
# bounsweet
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 69
#
# helioptile
# predicted: Electric
# real type: Electric and Normal
# SUCCESSFUL PREDICTIONS = 70
#
# venipede
# predicted: Normal
# real type: Bug and Poison
# Failed
#
# grotle
# predicted: Water
# real type: Grass
# Failed
#
# infernape
# predicted: Fire
# real type: Fire and Fighting
# SUCCESSFUL PREDICTIONS = 71
#
# poipole
# predicted: Dark
# real type: Poison
# Failed
#
# banette
# predicted: Rock
# real type: Ghost
# Failed
#
# hakamo-o
# predicted: Grass
# real type: Dragon and Fighting
# Failed
#
# electrode
# predicted: Bug
# real type: Electric
# Failed
#
# slakoth
# predicted: Ice
# real type: Normal
# Failed
#
# turtwig
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 72
#
# sawsbuck
# predicted: Fire
# real type: Normal and Grass
# Failed
#
# lunala
# predicted: Dark
# real type: Psychic and Ghost
# Failed
#
# persian
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 73
#
# pachirisu
# predicted: Water
# real type: Electric
# Failed
#
# whismur
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 74
#
# electrike
# predicted: Psychic
# real type: Electric
# Failed
#
# hitmontop
# predicted: Bug
# real type: Fighting
# Failed
#
# cacnea
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 75
#
# spiritomb
# predicted: Normal
# real type: Ghost and Dark
# Failed
#
# chatot
# predicted: Fire
# real type: Normal and Flying
# Failed
#
# squirtle
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 76
#
# vanillite
# predicted: Normal
# real type: Ice
# Failed
#
# tepig
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 77
#
# roselia
# predicted: Grass
# real type: Grass and Poison
# SUCCESSFUL PREDICTIONS = 78
#
# chimchar
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 79
#
# burmy
# predicted: Grass
# real type: Bug
# Failed
#
# groudon
# predicted: Fire
# real type: Ground
# Failed
#
# timburr
# predicted: Normal
# real type: Fighting
# Failed
#
# incineroar
# predicted: Bug
# real type: Fire and Dark
# Failed
#
# leavanny
# predicted: Bug
# real type: Bug and Grass
# SUCCESSFUL PREDICTIONS = 80
#
# gible
# predicted: Water
# real type: Dragon and Ground
# Failed
#
# solosis
# predicted: Psychic
# real type: Psychic
# SUCCESSFUL PREDICTIONS = 81
#
# corsola
# predicted: Grass
# real type: Water and Rock
# Failed
#
# drifblim
# predicted: Poison
# real type: Ghost and Flying
# Failed
#
# rockruff
# predicted: Water
# real type: Rock
# Failed
#
# yanma
# predicted: Ground
# real type: Bug and Flying
# Failed
#
# klinklang
# predicted: Fire
# real type: Steel
# Failed
#
# absol
# predicted: Fire
# real type: Dark
# Failed
#
# escavalier
# predicted: Grass
# real type: Bug and Steel
# Failed
#
# doublade
# predicted: Rock
# real type: Steel and Ghost
# Failed
#
# venomoth
# predicted: Dragon
# real type: Bug and Poison
# Failed
#
# staryu
# predicted: Rock
# real type: Water
# Failed
#
# diggersby
# predicted: Bug
# real type: Normal and Ground
# Failed
#
# watchog
# predicted: Fire
# real type: Normal
# Failed
#
# umbreon
# predicted: Bug
# real type: Dark
# Failed
#
# mawile
# predicted: Electric
# real type: Steel and Fairy
# Failed
#
# golisopod
# predicted: Normal
# real type: Bug and Water
# Failed
#
# wooper
# predicted: Water
# real type: Water and Ground
# SUCCESSFUL PREDICTIONS = 82
#
# volcanion
# predicted: Bug
# real type: Fire and Water
# Failed
#
# lillipup
# predicted: Ghost
# real type: Normal
# Failed
#
# rowlet
# predicted: Steel
# real type: Grass and Flying
# Failed
#
# lycanroc-midday
# predicted: Normal
# real type: Rock
# Failed
#
# primeape
# predicted: Normal
# real type: Fighting
# Failed
#
# seaking
# predicted: Grass
# real type: Water
# Failed
#
# weezing
# predicted: Normal
# real type: Poison
# Failed
#
# meganium
# predicted: Normal
# real type: Grass
# Failed
#
# fletchling
# predicted: Fire
# real type: Normal and Flying
# Failed
#
# flygon
# predicted: Grass
# real type: Ground and Dragon
# Failed
#
# clefairy
# predicted: Normal
# real type: Fairy
# Failed
#
# starmie
# predicted: Psychic
# real type: Water and Psychic
# SUCCESSFUL PREDICTIONS = 83
#
# tangela
# predicted: Dark
# real type: Grass
# Failed
#
# hippopotas
# predicted: Electric
# real type: Ground
# Failed
#
# blissey
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 84
#
# cherrim
# predicted: Dark
# real type: Grass
# Failed
#
# pangoro
# predicted: Rock
# real type: Fighting and Dark
# Failed
#
# venusaur
# predicted: Water
# real type: Grass and Poison
# Failed
#
# starly
# predicted: Ghost
# real type: Normal and Flying
# Failed
#
# guzzlord
# predicted: Bug
# real type: Dark and Dragon
# Failed
#
# herdier
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 85
#
# gurdurr
# predicted: Bug
# real type: Fighting
# Failed
#
# zygarde-50
# predicted: Normal
# real type: Dragon and Ground
# Failed
#
# wurmple
# predicted: Normal
# real type: Bug
# Failed
#
# caterpie
# predicted: Grass
# real type: Bug
# Failed
#
# lapras
# predicted: Water
# real type: Water and Ice
# SUCCESSFUL PREDICTIONS = 86
#
# frogadier
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 87
#
# mimikyu
# predicted: Electric
# real type: Ghost and Fairy
# Failed
#
# panpour
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 88
#
# tirtouga
# predicted: Dark
# real type: Water and Rock
# Failed
#
# wormadam-plant
# predicted: Normal
# real type: Bug and Grass
# Failed
#
# type-null
# predicted: Ghost
# real type: Normal
# Failed
#
# ariados
# predicted: Ground
# real type: Bug and Poison
# Failed
#
# sewaddle
# predicted: Bug
# real type: Bug and Grass
# SUCCESSFUL PREDICTIONS = 89
#
# whiscash
# predicted: Electric
# real type: Water and Ground
# Failed
#
# buizel
# predicted: Fire
# real type: Water
# Failed
#
# gourgeist-average
# predicted: Fire
# real type: Ghost and Grass
# Failed
#
# whimsicott
# predicted: Normal
# real type: Grass and Fairy
# Failed
#
# electabuzz
# predicted: Normal
# real type: Electric
# Failed
#
# floatzel
# predicted: Fire
# real type: Water
# Failed
#
# beedrill
# predicted: Grass
# real type: Bug and Poison
# Failed
#
# carvanha
# predicted: Rock
# real type: Water and Dark
# Failed
#
# pancham
# predicted: Psychic
# real type: Fighting
# Failed
#
# bisharp
# predicted: Rock
# real type: Dark and Steel
# Failed
#
# nidoqueen
# predicted: Water
# real type: Poison and Ground
# Failed
#
# surskit
# predicted: Psychic
# real type: Bug and Water
# Failed
#
# virizion
# predicted: Grass
# real type: Grass and Fighting
# SUCCESSFUL PREDICTIONS = 90
#
# sandile
# predicted: Ground
# real type: Ground and Dark
# SUCCESSFUL PREDICTIONS = 91
#
# mudbray
# predicted: Rock
# real type: Ground
# Failed
#
# meditite
# predicted: Fire
# real type: Fighting and Psychic
# Failed
#
# forretress
# predicted: Water
# real type: Bug and Steel
# Failed
#
# meowstic-male
# predicted: Water
# real type: Psychic
# Failed
#
# froslass
# predicted: Fighting
# real type: Ice and Ghost
# Failed
#
# archen
# predicted: Fire
# real type: Rock and Flying
# Failed
#
# pumpkaboo-average
# predicted: Bug
# real type: Ghost and Grass
# Failed
#
# fearow
# predicted: Fire
# real type: Normal and Flying
# Failed
#
# registeel
# predicted: Normal
# real type: Steel
# Failed
#
# arceus
# predicted: Fire
# real type: Normal
# Failed
#
# oshawott
# predicted: Water
# real type: Water
# SUCCESSFUL PREDICTIONS = 92
#
# seismitoad
# predicted: Water
# real type: Water and Ground
# SUCCESSFUL PREDICTIONS = 93
#
# cherubi
# predicted: Normal
# real type: Grass
# Failed
#
# jynx
# predicted: Fire
# real type: Ice and Psychic
# Failed
#
# ferrothorn
# predicted: Grass
# real type: Grass and Steel
# SUCCESSFUL PREDICTIONS = 94
#
# scrafty
# predicted: Bug
# real type: Dark and Fighting
# Failed
#
# darkrai
# predicted: Ghost
# real type: Dark
# Failed
#
# rufflet
# predicted: Normal
# real type: Normal and Flying
# SUCCESSFUL PREDICTIONS = 95
#
# furfrou
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 96
#
# lugia
# predicted: Dragon
# real type: Psychic and Flying
# Failed
#
# regirock
# predicted: Normal
# real type: Rock
# Failed
#
# magcargo
# predicted: Fire
# real type: Fire and Rock
# SUCCESSFUL PREDICTIONS = 97
#
# stantler
# predicted: Bug
# real type: Normal
# Failed
#
# glalie
# predicted: Ice
# real type: Ice
# SUCCESSFUL PREDICTIONS = 98
#
# jigglypuff
# predicted: Normal
# real type: Normal and Fairy
# SUCCESSFUL PREDICTIONS = 99
#
# grubbin
# predicted: Normal
# real type: Bug
# Failed
#
# golett
# predicted: Steel
# real type: Ground and Ghost
# Failed
#
# uxie
# predicted: Grass
# real type: Psychic
# Failed
#
# buneary
# predicted: Ice
# real type: Normal
# Failed
#
# zapdos
# predicted: Electric
# real type: Electric and Flying
# SUCCESSFUL PREDICTIONS = 100
#
# nihilego
# predicted: Water
# real type: Rock and Poison
# Failed
#
# minun
# predicted: Water
# real type: Electric
# Failed
#
# empoleon
# predicted: Fairy
# real type: Water and Steel
# Failed
#
# dewpider
# predicted: Steel
# real type: Water and Bug
# Failed
#
# sawk
# predicted: Steel
# real type: Fighting
# Failed
#
# flareon
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 101
#
# spinarak
# predicted: Grass
# real type: Bug and Poison
# Failed
#
# gligar
# predicted: Water
# real type: Ground and Flying
# Failed
#
# ninjask
# predicted: Grass
# real type: Bug and Flying
# Failed
#
# togekiss
# predicted: Bug
# real type: Fairy and Flying
# Failed
#
# yanmega
# predicted: Normal
# real type: Bug and Flying
# Failed
#
# vanillish
# predicted: Water
# real type: Ice
# Failed
#
# sigilyph
# predicted: Psychic
# real type: Psychic and Flying
# SUCCESSFUL PREDICTIONS = 102
#
# hitmonlee
# predicted: Water
# real type: Fighting
# Failed
#
# houndour
# predicted: Electric
# real type: Dark and Fire
# Failed
#
# nidoran-m
# predicted: Normal
# real type: Poison
# Failed
#
# clefable
# predicted: Normal
# real type: Fairy
# Failed
#
# latias
# predicted: Fire
# real type: Dragon and Psychic
# Failed
#
# archeops
# predicted: Fighting
# real type: Rock and Flying
# Failed
#
# skuntank
# predicted: Poison
# real type: Poison and Dark
# SUCCESSFUL PREDICTIONS = 103
#
# sandshrew
# predicted: Bug
# real type: Ground
# Failed
#
# machamp
# predicted: Bug
# real type: Fighting
# Failed
#
# omanyte
# predicted: Normal
# real type: Rock and Water
# Failed
#
# elgyem
# predicted: Water
# real type: Psychic
# Failed
#
# teddiursa
# predicted: Water
# real type: Normal
# Failed
#
# maractus
# predicted: Grass
# real type: Grass
# SUCCESSFUL PREDICTIONS = 104
#
# moltres
# predicted: Bug
# real type: Fire and Flying
# Failed
#
# aurorus
# predicted: Psychic
# real type: Rock and Ice
# Failed
#
# vileplume
# predicted: Fire
# real type: Grass and Poison
# Failed
#
# geodude
# predicted: Normal
# real type: Rock and Ground
# Failed
#
# throh
# predicted: Normal
# real type: Fighting
# Failed
#
# sunkern
# predicted: Electric
# real type: Grass
# Failed
#
# necrozma
# predicted: Psychic
# real type: Psychic
# SUCCESSFUL PREDICTIONS = 105
#
# marshtomp
# predicted: Water
# real type: Water and Ground
# SUCCESSFUL PREDICTIONS = 106
#
# minccino
# predicted: Normal
# real type: Normal
# SUCCESSFUL PREDICTIONS = 107
#
# charizard
# predicted: Electric
# real type: Fire and Flying
# Failed
#
# ninetales
# predicted: Fire
# real type: Fire
# SUCCESSFUL PREDICTIONS = 108
#
# tyrantrum
# predicted: Poison
# real type: Rock and Dragon
# Failed
#
# cascoon
# predicted: Fairy
# real type: Bug
# Failed
#
# ditto
# predicted: Water
# real type: Normal
# Failed
#
# gothorita
# predicted: Ghost
# real type: Psychic
# Failed
#
# pikipek
# predicted: Electric
# real type: Normal and Flying
# Failed
#
# haxorus
# predicted: Bug
# real type: Dragon
# Failed
#
# beartic
# predicted: Water
# real type: Ice
# Failed
#
# combusken
# predicted: Fire
# real type: Fire and Fighting
# SUCCESSFUL PREDICTIONS = 109
#
# garchomp
# predicted: Dark
# real type: Dragon and Ground
# Failed
#
# palkia
# predicted: Normal
# real type: Water and Dragon
# Failed
#
# bonsly
# predicted: Ground
# real type: Rock
# Failed
#
# cosmog
# predicted: Water
# real type: Psychic
# Failed
#
# budew
# predicted: Bug
# real type: Grass and Poison
# Failed
#
# munchlax
# predicted: Water
# real type: Normal
# Failed

# %%
accuracy = correct_predictions / len(y_test)
print(f'Accuracy: {np.round((accuracy*100),1)}%')
# Out:
# Accuracy: 26.9%

# %% [markdown]
# #### testing model (at least 1 predicted type from primary type)

# %%
correct_predictions = 0
for pred, truetype, truetype2, name in zip(y_pred, y_test, z_test, a_test):
    if pd.notna(truetype2) and truetype2 != '':
        print(f"\n{name}\npredicted: {pred}\nreal type: {truetype} and {truetype2}")
    else:
        print(f"\n{name}\npredicted: {pred}\nreal type: {truetype}")
    if pred == truetype:
        correct_predictions += 1
        print('SUCCESS')
    else: print(f"FAILED")
# Out:
# shiftry
# predicted: Ghost
# real type: Grass and Dark
# FAILED
#
# bellossom
# predicted: Electric
# real type: Grass
# FAILED
#
# skrelp
# predicted: Poison
# real type: Poison and Water
# SUCCESS
#
# bouffalant
# predicted: Dark
# real type: Normal
# FAILED
#
# mewtwo
# predicted: Dragon
# real type: Psychic
# FAILED
#
# duskull
# predicted: Grass
# real type: Ghost
# FAILED
#
# braixen
# predicted: Fire
# real type: Fire
# SUCCESS
#
# fomantis
# predicted: Grass
# real type: Grass
# SUCCESS
#
# magearna
# predicted: Normal
# real type: Steel and Fairy
# FAILED
#
# muk
# predicted: Ghost
# real type: Poison
# FAILED
#
# skiploom
# predicted: Bug
# real type: Grass and Flying
# FAILED
#
# tyranitar
# predicted: Grass
# real type: Rock and Dark
# FAILED
#
# ducklett
# predicted: Water
# real type: Water and Flying
# SUCCESS
#
# ralts
# predicted: Grass
# real type: Psychic and Fairy
# FAILED
#
# mienshao
# predicted: Fire
# real type: Fighting
# FAILED
#
# altaria
# predicted: Water
# real type: Dragon and Flying
# FAILED
#
# furret
# predicted: Normal
# real type: Normal
# SUCCESS
#
# dwebble
# predicted: Bug
# real type: Bug and Rock
# SUCCESS
#
# manectric
# predicted: Grass
# real type: Electric
# FAILED
#
# kyogre
# predicted: Water
# real type: Water
# SUCCESS
#
# xatu
# predicted: Bug
# real type: Psychic and Flying
# FAILED
#
# typhlosion
# predicted: Fire
# real type: Fire
# SUCCESS
#
# audino
# predicted: Normal
# real type: Normal
# SUCCESS
#
# weavile
# predicted: Bug
# real type: Dark and Ice
# FAILED
#
# magmar
# predicted: Fire
# real type: Fire
# SUCCESS
#
# mantine
# predicted: Fighting
# real type: Water and Flying
# FAILED
#
# arcanine
# predicted: Normal
# real type: Fire
# FAILED
#
# charjabug
# predicted: Grass
# real type: Bug and Electric
# FAILED
#
# lickitung
# predicted: Psychic
# real type: Normal
# FAILED
#
# mr-mime
# predicted: Water
# real type: Psychic and Fairy
# FAILED
#
# lickilicky
# predicted: Ground
# real type: Normal
# FAILED
#
# gliscor
# predicted: Poison
# real type: Ground and Flying
# FAILED
#
# tympole
# predicted: Normal
# real type: Water
# FAILED
#
# kricketune
# predicted: Fire
# real type: Bug
# FAILED
#
# treecko
# predicted: Grass
# real type: Grass
# SUCCESS
#
# seviper
# predicted: Electric
# real type: Poison
# FAILED
#
# tapu-fini
# predicted: Poison
# real type: Water and Fairy
# FAILED
#
# garbodor
# predicted: Dragon
# real type: Poison
# FAILED
#
# blitzle
# predicted: Electric
# real type: Electric
# SUCCESS
#
# swinub
# predicted: Normal
# real type: Ice and Ground
# FAILED
#
# cyndaquil
# predicted: Fire
# real type: Fire
# SUCCESS
#
# wartortle
# predicted: Psychic
# real type: Water
# FAILED
#
# lombre
# predicted: Grass
# real type: Water and Grass
# FAILED
#
# haunter
# predicted: Poison
# real type: Ghost and Poison
# FAILED
#
# charmeleon
# predicted: Fighting
# real type: Fire
# FAILED
#
# xerneas
# predicted: Water
# real type: Fairy
# FAILED
#
# shellder
# predicted: Electric
# real type: Water
# FAILED
#
# shedinja
# predicted: Bug
# real type: Bug and Ghost
# SUCCESS
#
# inkay
# predicted: Grass
# real type: Dark and Psychic
# FAILED
#
# druddigon
# predicted: Water
# real type: Dragon
# FAILED
#
# ekans
# predicted: Normal
# real type: Poison
# FAILED
#
# zangoose
# predicted: Steel
# real type: Normal
# FAILED
#
# klefki
# predicted: Fighting
# real type: Steel and Fairy
# FAILED
#
# nidorina
# predicted: Psychic
# real type: Poison
# FAILED
#
# bagon
# predicted: Water
# real type: Dragon
# FAILED
#
# dewott
# predicted: Water
# real type: Water
# SUCCESS
#
# keldeo-ordinary
# predicted: Water
# real type: Water and Fighting
# SUCCESS
#
# chikorita
# predicted: Psychic
# real type: Grass
# FAILED
#
# patrat
# predicted: Ice
# real type: Normal
# FAILED
#
# gulpin
# predicted: Psychic
# real type: Poison
# FAILED
#
# venonat
# predicted: Poison
# real type: Bug and Poison
# FAILED
#
# magnezone
# predicted: Normal
# real type: Electric and Steel
# FAILED
#
# noctowl
# predicted: Normal
# real type: Normal and Flying
# SUCCESS
#
# probopass
# predicted: Normal
# real type: Rock and Steel
# FAILED
#
# skarmory
# predicted: Dragon
# real type: Steel and Flying
# FAILED
#
# honchkrow
# predicted: Bug
# real type: Dark and Flying
# FAILED
#
# oddish
# predicted: Grass
# real type: Grass and Poison
# SUCCESS
#
# primarina
# predicted: Water
# real type: Water and Fairy
# SUCCESS
#
# gorebyss
# predicted: Psychic
# real type: Water
# FAILED
#
# blaziken
# predicted: Fire
# real type: Fire and Fighting
# SUCCESS
#
# kartana
# predicted: Fire
# real type: Grass and Steel
# FAILED
#
# shellos
# predicted: Normal
# real type: Water
# FAILED
#
# woobat
# predicted: Water
# real type: Psychic and Flying
# FAILED
#
# pidgeot
# predicted: Normal
# real type: Normal and Flying
# SUCCESS
#
# slurpuff
# predicted: Normal
# real type: Fairy
# FAILED
#
# diancie
# predicted: Poison
# real type: Rock and Fairy
# FAILED
#
# shieldon
# predicted: Ghost
# real type: Rock and Steel
# FAILED
#
# luxio
# predicted: Electric
# real type: Electric
# SUCCESS
#
# dialga
# predicted: Dark
# real type: Steel and Dragon
# FAILED
#
# florges
# predicted: Grass
# real type: Fairy
# FAILED
#
# dunsparce
# predicted: Water
# real type: Normal
# FAILED
#
# poliwrath
# predicted: Ice
# real type: Water and Fighting
# FAILED
#
# kabutops
# predicted: Psychic
# real type: Rock and Water
# FAILED
#
# tropius
# predicted: Grass
# real type: Grass and Flying
# SUCCESS
#
# beldum
# predicted: Water
# real type: Steel and Psychic
# FAILED
#
# igglybuff
# predicted: Normal
# real type: Normal and Fairy
# SUCCESS
#
# komala
# predicted: Water
# real type: Normal
# FAILED
#
# relicanth
# predicted: Bug
# real type: Water and Rock
# FAILED
#
# heliolisk
# predicted: Grass
# real type: Electric and Normal
# FAILED
#
# noibat
# predicted: Normal
# real type: Flying and Dragon
# FAILED
#
# paras
# predicted: Bug
# real type: Bug and Grass
# SUCCESS
#
# zoroark
# predicted: Ghost
# real type: Dark
# FAILED
#
# torterra
# predicted: Grass
# real type: Grass and Ground
# SUCCESS
#
# donphan
# predicted: Rock
# real type: Ground
# FAILED
#
# zweilous
# predicted: Poison
# real type: Dark and Dragon
# FAILED
#
# lurantis
# predicted: Water
# real type: Grass
# FAILED
#
# espeon
# predicted: Normal
# real type: Psychic
# FAILED
#
# snubbull
# predicted: Grass
# real type: Fairy
# FAILED
#
# porygon
# predicted: Water
# real type: Normal
# FAILED
#
# fennekin
# predicted: Fire
# real type: Fire
# SUCCESS
#
# togedemaru
# predicted: Dragon
# real type: Electric and Steel
# FAILED
#
# whirlipede
# predicted: Normal
# real type: Bug and Poison
# FAILED
#
# spheal
# predicted: Electric
# real type: Ice and Water
# FAILED
#
# stakataka
# predicted: Rock
# real type: Rock and Steel
# SUCCESS
#
# cloyster
# predicted: Normal
# real type: Water and Ice
# FAILED
#
# koffing
# predicted: Poison
# real type: Poison
# SUCCESS
#
# heracross
# predicted: Water
# real type: Bug and Fighting
# FAILED
#
# golurk
# predicted: Grass
# real type: Ground and Ghost
# FAILED
#
# bronzong
# predicted: Grass
# real type: Steel and Psychic
# FAILED
#
# mesprit
# predicted: Normal
# real type: Psychic
# FAILED
#
# litwick
# predicted: Ice
# real type: Ghost and Fire
# FAILED
#
# emboar
# predicted: Bug
# real type: Fire and Fighting
# FAILED
#
# vivillon
# predicted: Normal
# real type: Bug and Flying
# FAILED
#
# sceptile
# predicted: Grass
# real type: Grass
# SUCCESS
#
# delibird
# predicted: Fire
# real type: Ice and Flying
# FAILED
#
# prinplup
# predicted: Water
# real type: Water
# SUCCESS
#
# seel
# predicted: Bug
# real type: Water
# FAILED
#
# braviary
# predicted: Electric
# real type: Normal and Flying
# FAILED
#
# palpitoad
# predicted: Steel
# real type: Water and Ground
# FAILED
#
# vulpix
# predicted: Fire
# real type: Fire
# SUCCESS
#
# kyurem
# predicted: Water
# real type: Dragon and Ice
# FAILED
#
# diglett
# predicted: Normal
# real type: Ground
# FAILED
#
# krokorok
# predicted: Ground
# real type: Ground and Dark
# SUCCESS
#
# golem
# predicted: Rock
# real type: Rock and Ground
# SUCCESS
#
# riolu
# predicted: Poison
# real type: Fighting
# FAILED
#
# swellow
# predicted: Normal
# real type: Normal and Flying
# SUCCESS
#
# spearow
# predicted: Rock
# real type: Normal and Flying
# FAILED
#
# exeggcute
# predicted: Normal
# real type: Grass and Psychic
# FAILED
#
# mandibuzz
# predicted: Ghost
# real type: Dark and Flying
# FAILED
#
# pignite
# predicted: Fire
# real type: Fire and Fighting
# SUCCESS
#
# gothitelle
# predicted: Ghost
# real type: Psychic
# FAILED
#
# huntail
# predicted: Rock
# real type: Water
# FAILED
#
# pelipper
# predicted: Water
# real type: Water and Flying
# SUCCESS
#
# heatmor
# predicted: Fire
# real type: Fire
# SUCCESS
#
# lotad
# predicted: Grass
# real type: Water and Grass
# FAILED
#
# marill
# predicted: Normal
# real type: Water and Fairy
# FAILED
#
# goldeen
# predicted: Grass
# real type: Water
# FAILED
#
# plusle
# predicted: Ground
# real type: Electric
# FAILED
#
# lileep
# predicted: Normal
# real type: Rock and Grass
# FAILED
#
# aron
# predicted: Dragon
# real type: Steel and Rock
# FAILED
#
# poliwhirl
# predicted: Fighting
# real type: Water
# FAILED
#
# larvitar
# predicted: Grass
# real type: Rock and Ground
# FAILED
#
# serperior
# predicted: Grass
# real type: Grass
# SUCCESS
#
# marshadow
# predicted: Steel
# real type: Fighting and Ghost
# FAILED
#
# rotom
# predicted: Water
# real type: Electric and Ghost
# FAILED
#
# blastoise
# predicted: Fighting
# real type: Water
# FAILED
#
# breloom
# predicted: Grass
# real type: Grass and Fighting
# SUCCESS
#
# mew
# predicted: Psychic
# real type: Psychic
# SUCCESS
#
# finneon
# predicted: Ground
# real type: Water
# FAILED
#
# remoraid
# predicted: Normal
# real type: Water
# FAILED
#
# scyther
# predicted: Grass
# real type: Bug and Flying
# FAILED
#
# magikarp
# predicted: Fire
# real type: Water
# FAILED
#
# torchic
# predicted: Psychic
# real type: Fire
# FAILED
#
# delcatty
# predicted: Normal
# real type: Normal
# SUCCESS
#
# glaceon
# predicted: Grass
# real type: Ice
# FAILED
#
# axew
# predicted: Ghost
# real type: Dragon
# FAILED
#
# litleo
# predicted: Ghost
# real type: Fire and Normal
# FAILED
#
# voltorb
# predicted: Ground
# real type: Electric
# FAILED
#
# mismagius
# predicted: Dark
# real type: Ghost
# FAILED
#
# pikachu
# predicted: Electric
# real type: Electric
# SUCCESS
#
# yveltal
# predicted: Ghost
# real type: Dark and Flying
# FAILED
#
# ludicolo
# predicted: Grass
# real type: Water and Grass
# FAILED
#
# aerodactyl
# predicted: Poison
# real type: Rock and Flying
# FAILED
#
# golbat
# predicted: Poison
# real type: Poison and Flying
# SUCCESS
#
# lumineon
# predicted: Water
# real type: Water
# SUCCESS
#
# marowak
# predicted: Normal
# real type: Ground
# FAILED
#
# mudkip
# predicted: Electric
# real type: Water
# FAILED
#
# sylveon
# predicted: Normal
# real type: Fairy
# FAILED
#
# galvantula
# predicted: Electric
# real type: Bug and Electric
# FAILED
#
# anorith
# predicted: Grass
# real type: Rock and Bug
# FAILED
#
# bewear
# predicted: Psychic
# real type: Normal and Fighting
# FAILED
#
# masquerain
# predicted: Water
# real type: Bug and Flying
# FAILED
#
# exploud
# predicted: Water
# real type: Normal
# FAILED
#
# sentret
# predicted: Ground
# real type: Normal
# FAILED
#
# camerupt
# predicted: Fairy
# real type: Fire and Ground
# FAILED
#
# tranquill
# predicted: Normal
# real type: Normal and Flying
# SUCCESS
#
# swampert
# predicted: Water
# real type: Water and Ground
# SUCCESS
#
# nuzleaf
# predicted: Rock
# real type: Grass and Dark
# FAILED
#
# quilladin
# predicted: Grass
# real type: Grass
# SUCCESS
#
# ursaring
# predicted: Bug
# real type: Normal
# FAILED
#
# wailord
# predicted: Water
# real type: Water
# SUCCESS
#
# regice
# predicted: Water
# real type: Ice
# FAILED
#
# amaura
# predicted: Water
# real type: Rock and Ice
# FAILED
#
# arbok
# predicted: Normal
# real type: Poison
# FAILED
#
# cosmoem
# predicted: Normal
# real type: Psychic
# FAILED
#
# octillery
# predicted: Fire
# real type: Water
# FAILED
#
# trubbish
# predicted: Dragon
# real type: Poison
# FAILED
#
# latios
# predicted: Water
# real type: Dragon and Psychic
# FAILED
#
# mime-jr
# predicted: Normal
# real type: Psychic and Fairy
# FAILED
#
# decidueye
# predicted: Normal
# real type: Grass and Ghost
# FAILED
#
# scraggy
# predicted: Water
# real type: Dark and Fighting
# FAILED
#
# leafeon
# predicted: Grass
# real type: Grass
# SUCCESS
#
# vespiquen
# predicted: Bug
# real type: Bug and Flying
# SUCCESS
#
# luxray
# predicted: Electric
# real type: Electric
# SUCCESS
#
# goodra
# predicted: Dragon
# real type: Dragon
# SUCCESS
#
# azurill
# predicted: Water
# real type: Normal and Fairy
# FAILED
#
# solgaleo
# predicted: Fire
# real type: Psychic and Steel
# FAILED
#
# dustox
# predicted: Grass
# real type: Bug and Poison
# FAILED
#
# elekid
# predicted: Electric
# real type: Electric
# SUCCESS
#
# carnivine
# predicted: Grass
# real type: Grass
# SUCCESS
#
# zubat
# predicted: Poison
# real type: Poison and Flying
# SUCCESS
#
# glameow
# predicted: Bug
# real type: Normal
# FAILED
#
# oricorio-baile
# predicted: Fire
# real type: Fire and Flying
# SUCCESS
#
# jirachi
# predicted: Electric
# real type: Steel and Psychic
# FAILED
#
# luvdisc
# predicted: Psychic
# real type: Water
# FAILED
#
# wobbuffet
# predicted: Water
# real type: Psychic
# FAILED
#
# gengar
# predicted: Ghost
# real type: Ghost and Poison
# SUCCESS
#
# combee
# predicted: Bug
# real type: Bug and Flying
# SUCCESS
#
# lanturn
# predicted: Poison
# real type: Water and Electric
# FAILED
#
# girafarig
# predicted: Water
# real type: Normal and Psychic
# FAILED
#
# lampent
# predicted: Psychic
# real type: Ghost and Fire
# FAILED
#
# cofagrigus
# predicted: Ghost
# real type: Ghost
# SUCCESS
#
# gumshoos
# predicted: Rock
# real type: Normal
# FAILED
#
# raikou
# predicted: Psychic
# real type: Electric
# FAILED
#
# celesteela
# predicted: Grass
# real type: Steel and Flying
# FAILED
#
# tapu-lele
# predicted: Ground
# real type: Psychic and Fairy
# FAILED
#
# gothita
# predicted: Fighting
# real type: Psychic
# FAILED
#
# hypno
# predicted: Psychic
# real type: Psychic
# SUCCESS
#
# gallade
# predicted: Grass
# real type: Psychic and Fighting
# FAILED
#
# unfezant
# predicted: Rock
# real type: Normal and Flying
# FAILED
#
# ledyba
# predicted: Fairy
# real type: Bug and Flying
# FAILED
#
# castform
# predicted: Dragon
# real type: Normal
# FAILED
#
# excadrill
# predicted: Dark
# real type: Ground and Steel
# FAILED
#
# cacturne
# predicted: Grass
# real type: Grass and Dark
# SUCCESS
#
# spritzee
# predicted: Psychic
# real type: Fairy
# FAILED
#
# hawlucha
# predicted: Grass
# real type: Fighting and Flying
# FAILED
#
# sandslash
# predicted: Normal
# real type: Ground
# FAILED
#
# bounsweet
# predicted: Grass
# real type: Grass
# SUCCESS
#
# helioptile
# predicted: Electric
# real type: Electric and Normal
# SUCCESS
#
# venipede
# predicted: Normal
# real type: Bug and Poison
# FAILED
#
# grotle
# predicted: Water
# real type: Grass
# FAILED
#
# infernape
# predicted: Fire
# real type: Fire and Fighting
# SUCCESS
#
# poipole
# predicted: Dark
# real type: Poison
# FAILED
#
# banette
# predicted: Rock
# real type: Ghost
# FAILED
#
# hakamo-o
# predicted: Grass
# real type: Dragon and Fighting
# FAILED
#
# electrode
# predicted: Bug
# real type: Electric
# FAILED
#
# slakoth
# predicted: Ice
# real type: Normal
# FAILED
#
# turtwig
# predicted: Grass
# real type: Grass
# SUCCESS
#
# sawsbuck
# predicted: Fire
# real type: Normal and Grass
# FAILED
#
# lunala
# predicted: Dark
# real type: Psychic and Ghost
# FAILED
#
# persian
# predicted: Normal
# real type: Normal
# SUCCESS
#
# pachirisu
# predicted: Water
# real type: Electric
# FAILED
#
# whismur
# predicted: Normal
# real type: Normal
# SUCCESS
#
# electrike
# predicted: Psychic
# real type: Electric
# FAILED
#
# hitmontop
# predicted: Bug
# real type: Fighting
# FAILED
#
# cacnea
# predicted: Grass
# real type: Grass
# SUCCESS
#
# spiritomb
# predicted: Normal
# real type: Ghost and Dark
# FAILED
#
# chatot
# predicted: Fire
# real type: Normal and Flying
# FAILED
#
# squirtle
# predicted: Water
# real type: Water
# SUCCESS
#
# vanillite
# predicted: Normal
# real type: Ice
# FAILED
#
# tepig
# predicted: Fire
# real type: Fire
# SUCCESS
#
# roselia
# predicted: Grass
# real type: Grass and Poison
# SUCCESS
#
# chimchar
# predicted: Fire
# real type: Fire
# SUCCESS
#
# burmy
# predicted: Grass
# real type: Bug
# FAILED
#
# groudon
# predicted: Fire
# real type: Ground
# FAILED
#
# timburr
# predicted: Normal
# real type: Fighting
# FAILED
#
# incineroar
# predicted: Bug
# real type: Fire and Dark
# FAILED
#
# leavanny
# predicted: Bug
# real type: Bug and Grass
# SUCCESS
#
# gible
# predicted: Water
# real type: Dragon and Ground
# FAILED
#
# solosis
# predicted: Psychic
# real type: Psychic
# SUCCESS
#
# corsola
# predicted: Grass
# real type: Water and Rock
# FAILED
#
# drifblim
# predicted: Poison
# real type: Ghost and Flying
# FAILED
#
# rockruff
# predicted: Water
# real type: Rock
# FAILED
#
# yanma
# predicted: Ground
# real type: Bug and Flying
# FAILED
#
# klinklang
# predicted: Fire
# real type: Steel
# FAILED
#
# absol
# predicted: Fire
# real type: Dark
# FAILED
#
# escavalier
# predicted: Grass
# real type: Bug and Steel
# FAILED
#
# doublade
# predicted: Rock
# real type: Steel and Ghost
# FAILED
#
# venomoth
# predicted: Dragon
# real type: Bug and Poison
# FAILED
#
# staryu
# predicted: Rock
# real type: Water
# FAILED
#
# diggersby
# predicted: Bug
# real type: Normal and Ground
# FAILED
#
# watchog
# predicted: Fire
# real type: Normal
# FAILED
#
# umbreon
# predicted: Bug
# real type: Dark
# FAILED
#
# mawile
# predicted: Electric
# real type: Steel and Fairy
# FAILED
#
# golisopod
# predicted: Normal
# real type: Bug and Water
# FAILED
#
# wooper
# predicted: Water
# real type: Water and Ground
# SUCCESS
#
# volcanion
# predicted: Bug
# real type: Fire and Water
# FAILED
#
# lillipup
# predicted: Ghost
# real type: Normal
# FAILED
#
# rowlet
# predicted: Steel
# real type: Grass and Flying
# FAILED
#
# lycanroc-midday
# predicted: Normal
# real type: Rock
# FAILED
#
# primeape
# predicted: Normal
# real type: Fighting
# FAILED
#
# seaking
# predicted: Grass
# real type: Water
# FAILED
#
# weezing
# predicted: Normal
# real type: Poison
# FAILED
#
# meganium
# predicted: Normal
# real type: Grass
# FAILED
#
# fletchling
# predicted: Fire
# real type: Normal and Flying
# FAILED
#
# flygon
# predicted: Grass
# real type: Ground and Dragon
# FAILED
#
# clefairy
# predicted: Normal
# real type: Fairy
# FAILED
#
# starmie
# predicted: Psychic
# real type: Water and Psychic
# FAILED
#
# tangela
# predicted: Dark
# real type: Grass
# FAILED
#
# hippopotas
# predicted: Electric
# real type: Ground
# FAILED
#
# blissey
# predicted: Normal
# real type: Normal
# SUCCESS
#
# cherrim
# predicted: Dark
# real type: Grass
# FAILED
#
# pangoro
# predicted: Rock
# real type: Fighting and Dark
# FAILED
#
# venusaur
# predicted: Water
# real type: Grass and Poison
# FAILED
#
# starly
# predicted: Ghost
# real type: Normal and Flying
# FAILED
#
# guzzlord
# predicted: Bug
# real type: Dark and Dragon
# FAILED
#
# herdier
# predicted: Normal
# real type: Normal
# SUCCESS
#
# gurdurr
# predicted: Bug
# real type: Fighting
# FAILED
#
# zygarde-50
# predicted: Normal
# real type: Dragon and Ground
# FAILED
#
# wurmple
# predicted: Normal
# real type: Bug
# FAILED
#
# caterpie
# predicted: Grass
# real type: Bug
# FAILED
#
# lapras
# predicted: Water
# real type: Water and Ice
# SUCCESS
#
# frogadier
# predicted: Water
# real type: Water
# SUCCESS
#
# mimikyu
# predicted: Electric
# real type: Ghost and Fairy
# FAILED
#
# panpour
# predicted: Water
# real type: Water
# SUCCESS
#
# tirtouga
# predicted: Dark
# real type: Water and Rock
# FAILED
#
# wormadam-plant
# predicted: Normal
# real type: Bug and Grass
# FAILED
#
# type-null
# predicted: Ghost
# real type: Normal
# FAILED
#
# ariados
# predicted: Ground
# real type: Bug and Poison
# FAILED
#
# sewaddle
# predicted: Bug
# real type: Bug and Grass
# SUCCESS
#
# whiscash
# predicted: Electric
# real type: Water and Ground
# FAILED
#
# buizel
# predicted: Fire
# real type: Water
# FAILED
#
# gourgeist-average
# predicted: Fire
# real type: Ghost and Grass
# FAILED
#
# whimsicott
# predicted: Normal
# real type: Grass and Fairy
# FAILED
#
# electabuzz
# predicted: Normal
# real type: Electric
# FAILED
#
# floatzel
# predicted: Fire
# real type: Water
# FAILED
#
# beedrill
# predicted: Grass
# real type: Bug and Poison
# FAILED
#
# carvanha
# predicted: Rock
# real type: Water and Dark
# FAILED
#
# pancham
# predicted: Psychic
# real type: Fighting
# FAILED
#
# bisharp
# predicted: Rock
# real type: Dark and Steel
# FAILED
#
# nidoqueen
# predicted: Water
# real type: Poison and Ground
# FAILED
#
# surskit
# predicted: Psychic
# real type: Bug and Water
# FAILED
#
# virizion
# predicted: Grass
# real type: Grass and Fighting
# SUCCESS
#
# sandile
# predicted: Ground
# real type: Ground and Dark
# SUCCESS
#
# mudbray
# predicted: Rock
# real type: Ground
# FAILED
#
# meditite
# predicted: Fire
# real type: Fighting and Psychic
# FAILED
#
# forretress
# predicted: Water
# real type: Bug and Steel
# FAILED
#
# meowstic-male
# predicted: Water
# real type: Psychic
# FAILED
#
# froslass
# predicted: Fighting
# real type: Ice and Ghost
# FAILED
#
# archen
# predicted: Fire
# real type: Rock and Flying
# FAILED
#
# pumpkaboo-average
# predicted: Bug
# real type: Ghost and Grass
# FAILED
#
# fearow
# predicted: Fire
# real type: Normal and Flying
# FAILED
#
# registeel
# predicted: Normal
# real type: Steel
# FAILED
#
# arceus
# predicted: Fire
# real type: Normal
# FAILED
#
# oshawott
# predicted: Water
# real type: Water
# SUCCESS
#
# seismitoad
# predicted: Water
# real type: Water and Ground
# SUCCESS
#
# cherubi
# predicted: Normal
# real type: Grass
# FAILED
#
# jynx
# predicted: Fire
# real type: Ice and Psychic
# FAILED
#
# ferrothorn
# predicted: Grass
# real type: Grass and Steel
# SUCCESS
#
# scrafty
# predicted: Bug
# real type: Dark and Fighting
# FAILED
#
# darkrai
# predicted: Ghost
# real type: Dark
# FAILED
#
# rufflet
# predicted: Normal
# real type: Normal and Flying
# SUCCESS
#
# furfrou
# predicted: Normal
# real type: Normal
# SUCCESS
#
# lugia
# predicted: Dragon
# real type: Psychic and Flying
# FAILED
#
# regirock
# predicted: Normal
# real type: Rock
# FAILED
#
# magcargo
# predicted: Fire
# real type: Fire and Rock
# SUCCESS
#
# stantler
# predicted: Bug
# real type: Normal
# FAILED
#
# glalie
# predicted: Ice
# real type: Ice
# SUCCESS
#
# jigglypuff
# predicted: Normal
# real type: Normal and Fairy
# SUCCESS
#
# grubbin
# predicted: Normal
# real type: Bug
# FAILED
#
# golett
# predicted: Steel
# real type: Ground and Ghost
# FAILED
#
# uxie
# predicted: Grass
# real type: Psychic
# FAILED
#
# buneary
# predicted: Ice
# real type: Normal
# FAILED
#
# zapdos
# predicted: Electric
# real type: Electric and Flying
# SUCCESS
#
# nihilego
# predicted: Water
# real type: Rock and Poison
# FAILED
#
# minun
# predicted: Water
# real type: Electric
# FAILED
#
# empoleon
# predicted: Fairy
# real type: Water and Steel
# FAILED
#
# dewpider
# predicted: Steel
# real type: Water and Bug
# FAILED
#
# sawk
# predicted: Steel
# real type: Fighting
# FAILED
#
# flareon
# predicted: Fire
# real type: Fire
# SUCCESS
#
# spinarak
# predicted: Grass
# real type: Bug and Poison
# FAILED
#
# gligar
# predicted: Water
# real type: Ground and Flying
# FAILED
#
# ninjask
# predicted: Grass
# real type: Bug and Flying
# FAILED
#
# togekiss
# predicted: Bug
# real type: Fairy and Flying
# FAILED
#
# yanmega
# predicted: Normal
# real type: Bug and Flying
# FAILED
#
# vanillish
# predicted: Water
# real type: Ice
# FAILED
#
# sigilyph
# predicted: Psychic
# real type: Psychic and Flying
# SUCCESS
#
# hitmonlee
# predicted: Water
# real type: Fighting
# FAILED
#
# houndour
# predicted: Electric
# real type: Dark and Fire
# FAILED
#
# nidoran-m
# predicted: Normal
# real type: Poison
# FAILED
#
# clefable
# predicted: Normal
# real type: Fairy
# FAILED
#
# latias
# predicted: Fire
# real type: Dragon and Psychic
# FAILED
#
# archeops
# predicted: Fighting
# real type: Rock and Flying
# FAILED
#
# skuntank
# predicted: Poison
# real type: Poison and Dark
# SUCCESS
#
# sandshrew
# predicted: Bug
# real type: Ground
# FAILED
#
# machamp
# predicted: Bug
# real type: Fighting
# FAILED
#
# omanyte
# predicted: Normal
# real type: Rock and Water
# FAILED
#
# elgyem
# predicted: Water
# real type: Psychic
# FAILED
#
# teddiursa
# predicted: Water
# real type: Normal
# FAILED
#
# maractus
# predicted: Grass
# real type: Grass
# SUCCESS
#
# moltres
# predicted: Bug
# real type: Fire and Flying
# FAILED
#
# aurorus
# predicted: Psychic
# real type: Rock and Ice
# FAILED
#
# vileplume
# predicted: Fire
# real type: Grass and Poison
# FAILED
#
# geodude
# predicted: Normal
# real type: Rock and Ground
# FAILED
#
# throh
# predicted: Normal
# real type: Fighting
# FAILED
#
# sunkern
# predicted: Electric
# real type: Grass
# FAILED
#
# necrozma
# predicted: Psychic
# real type: Psychic
# SUCCESS
#
# marshtomp
# predicted: Water
# real type: Water and Ground
# SUCCESS
#
# minccino
# predicted: Normal
# real type: Normal
# SUCCESS
#
# charizard
# predicted: Electric
# real type: Fire and Flying
# FAILED
#
# ninetales
# predicted: Fire
# real type: Fire
# SUCCESS
#
# tyrantrum
# predicted: Poison
# real type: Rock and Dragon
# FAILED
#
# cascoon
# predicted: Fairy
# real type: Bug
# FAILED
#
# ditto
# predicted: Water
# real type: Normal
# FAILED
#
# gothorita
# predicted: Ghost
# real type: Psychic
# FAILED
#
# pikipek
# predicted: Electric
# real type: Normal and Flying
# FAILED
#
# haxorus
# predicted: Bug
# real type: Dragon
# FAILED
#
# beartic
# predicted: Water
# real type: Ice
# FAILED
#
# combusken
# predicted: Fire
# real type: Fire and Fighting
# SUCCESS
#
# garchomp
# predicted: Dark
# real type: Dragon and Ground
# FAILED
#
# palkia
# predicted: Normal
# real type: Water and Dragon
# FAILED
#
# bonsly
# predicted: Ground
# real type: Rock
# FAILED
#
# cosmog
# predicted: Water
# real type: Psychic
# FAILED
#
# budew
# predicted: Bug
# real type: Grass and Poison
# FAILED
#
# munchlax
# predicted: Water
# real type: Normal
# FAILED

# %%
accuracy = correct_predictions / len(y_test)
print(f'Accuracy: {np.round((accuracy*100),1)}%')
# Out:
# Accuracy: 25.2%
